# %%
import pandas as pd
df = pd.read_csv("data/sales.csv",usecols=['订单号',"产品类别",'产品名称','销售数量','单价'])

# 数据梳理 添加一列 销售金额
df['销售金额'] = df['销售数量'] * df['单价']

df.to_csv("data/sales_new.csv",index=False)

# %%
# 数据查看 --> head 、tail、info、describe,info,shape,column
df1 = pd.read_csv("data/sales.csv",usecols=['订单号',"产品类别",'产品名称','销售数量','单价'])

df1.head(10) # 查看前10行
df1.tail(10) # 查看最后10行
df1.describe() # 显示数据统计信息
df1.info() # 显示数据信息(列名，非空计数，数据类型 、内存使用情况)

# df1.shape # 显示数据集的行数和列数
df1.columns # 显示数据集的列名
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   订单号     1000 non-null   int64
#  1   产品类别    1000 non-null   str
#  2   产品名称    1000 non-null   str
#  3   销售数量    1000 non-null   int64
#  4   单价      1000 non-null   int64
# dtypes: int64(3), str(2)
# memory usage: 55.0 KB
# Index(['订单号', '产品类别', '产品名称', '销售数量', '单价'], dtype='str')

# %%
# 数据选择

df2 = pd.read_csv("data/sales.csv",usecols=['订单号',"产品类别",'产品名称','销售数量','单价'],index_col="订单号")
 # 1.选择列
 #1.1 单列
# df2['产品名称']
# df2.产品名称

# 1.2 多列
# df2[['产品名称','销售数量']]

# 2.选择行 -
# 2.1.iloc: 基于行号选择行(不包含结束位置), 语法:df.iloc[start:stop:step]

# df2.iloc[0:5:1]
# df2.iloc[0:40]

#2.2 loc: 索引值选择行
df2.loc[6805677496:6867258691:4]
# Out:
#             产品类别 产品名称  销售数量   单价
# 订单号
# 6805677496  家居用品   枕头    10  199
# 6801664364    食品   薯片     2   19
# 5875402232  电子产品  路由器     9  299
# 5891597362  电子产品   鼠标     3   89
# 5812573980    食品   坚果     2   79
# 6893087111    食品   蜂蜜    10   89
